# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
pd.options.display.float_format = '{:.0f}'.format
from pycoingecko import CoinGeckoAPI
cg = CoinGeckoAPI()

# %%
data = cg.get_price(ids =[
     "Bitcoin", "Ethereum", "Tether", "XRP", "BNB", "Solana", "USDC", "Cardano", "Dogecoin", "TRON",
    "Lido Staked Ether", "Wrapped Bitcoin", "Pi Network", "LEO Token", "Chainlink", "Hedera", "Wrapped stETH",
    "USDS", "Stellar", "Avalanche", "Sui", "Litecoin", "Bitcoin Cash", "Shiba Inu", "Toncoin", "Polkadot",
    "MANTRA", "WETH", "Ethena USDe", "Bitget Token", "Hyperliquid", "Wrapped eETH", "WhiteBIT Coin", "Monero",
    "Uniswap", "Aptos", "sUSDS", "Dai", "NEAR Protocol", "Ondo", "Ethereum Classic", "Aave", "Internet Computer",
    "Pepe", "OKB", "Gate", "Coinbase Wrapped BTC", "Mantle", "Ethena", "Cronos", "Official Trump", "Tokenize Xchange",
    "VeChain", "First Digital USD", "Bittensor", "POL (ex-MATIC)", "Filecoin", "Algorand", "Fasttoken", "Lombard Staked BTC",
    "Cosmos Hub", "Celestia", "Kaspa", "Render", "Arbitrum", "Sonic (prev. FTM)", "Optimism", "KuCoin", "Jupiter",
    "Artificial Superintelligence Alliance", "Story", "Solv Protocol SolvBTC", "Binance-Peg WETH", "Movement", "Kelp DAO Restaked ETH",
    "Quant", "XDC Network", "NEXO", "DeXe", "Maker", "Rocket Pool ETH", "Usual USD", "Flare", "Stacks", "Sei", "Injective",
    "Lido DAO", "Mantle Staked Ether", "Immutable", "Theta Network", "Worldcoin", "Binance Staked SOL", "The Graph",
    "Solv Protocol SolvBTC.BBN", "Bonk", "PayPal USD", "EOS", "Tether Gold", "Tezos", "Binance Bridged USDC (BNB Smart Chain)",
    "BitTorrent", "GALA", "Wrapped BNB", "Arbitrum Bridged WBTC (Arbitrum One)", "The Sandbox", "JasmyCoin", "Jito",
    "Berachain", "IOTA", "Bitcoin SV", "Renzo Restaked ETH", "Marinade Staked SOL", "Kaia", "Stables Labs USDX",
    "BlackRock USD Institutional Digital Liquidity Fund", "Flow", "PAX Gold", "Ethereum Name Service", "FLOKI", "NEO",
    "Resolv USR", "Telcoin", "Jupiter Staked SOL", "Pyth Network", "Honey", "MultiversX", "Helium", "Ronin", "Frax",
    "TrueUSD", "Raydium", "Curve DAO", "Axie Infinity", "L2 Standard Bridged WETH (Base)", "Decentraland", "Beldex",
    "Zcash", "Mantle Restaked ETH", "Arbitrum Bridged WETH (Arbitrum One)", "pumpBTC", "Kava", "dogwifhat",
    "Bridged USDC (Polygon PoS Bridge)", "PancakeSwap", "APENFT", "Aerodrome Finance", "dYdX", "Binance-Peg Dogecoin",
    "Starknet", "THORChain", "Avalanche Bridged BTC (Avalanche)", "ether.fi Staked ETH", "Arweave", "Grass", "Conflux",
    "Onyxcoin", "Chiliz", "clBTC", "Virtuals Protocol", "OUSG", "USDB", "Hashnote USYC", "eCash", "Polygon",
    "Trust Wallet", "Core", "Ondo US Dollar Yield", "Compound", "ApeCoin", "SPX6900", "Olympus", "cgETH Hashkey Cloud",
    "Infrared Bera", "KAITO", "StakeWise Staked ETH", "tBTC", "Axelar", "Pudgy Penguins", "Amp", "Pendle", "Gnosis",
    "Mantle Bridged USDT (Mantle)", "Binance-Peg BUSD", "StakeStone Berachain Vault Token", "Verus", "Terra Luna Classic",
    "Mina Protocol", "Brett", "JUST", "AIOZ Network", "Morpho", "Elixir deUSD", "Beam", "Coinbase Wrapped Staked ETH",
    "Reserve Rights", "Polygon PoS Bridged WETH (Polygon POS)", "Plume", "1inch", "Akash Network", "Eigenlayer", "Stader ETHx",
    "Synthetix Network", "MX", "SafePal", "Frax Ether", "Theta Fuel", "Dash", "Kusama", "Swell Ethereum", "cWBTC", "Super OETH",
    "Golem", "Polygon Bridged WBTC (Polygon POS)", "Ether.fi Staked BTC", "ZKsync", "Creditcoin", "SATS (Ordinals)", "Wormhole",
    "AI Companions", "Quorium", "Fartcoin", "Blur", "Snek", "Astar", "Zilliqa", "Safe", "Basic Attention", "USDD", "Nervos Network",
    "Liquid Staked ETH", "SuperVerse", "Qtum", "Mask Network", "ai16z", "Aethir", "Livepeer", "WEMIX", "Oasis", "dYdX", "0x Protocol",
    "Fluid", "DeepBook", "VeThor", "GHO", "Notcoin", "Staked Frax Ether", "USDa", "LayerZero", "Holo", "MEOW", "CHEX Token", "Chia",
    "Celo", "Stargate Finance", "Echelon Prime", "BTSE Token", "OriginTrail", "Cheems Token", "Osmosis", "Dog (Bitcoin)", "Act I The AI Prophecy",
    "SwissBorg", "Resolv wstUSR", "Baby Doge Coin", "AgentFun.AI", "Gas", "Arkham", "Bridged Ether (StarkGate)", "Decred", "MimbleWimbleCoin",
    "aBTC", "APF coin", "Siacoin", "Acet", "NEM", "Rollbit Coin", "Treehouse ETH", "Ankr Network", "Mog Coin", "Drift Protocol", "Tribe",
    "GoMining Token", "yearn.finance", "Solayer", "DigiByte", "RCGE", "Ravencoin", "BENQI Liquid Staked AVAX", "ORDI", "Moca Network", "Popcat",
    "Elixir Staked deUSD", "aelf", "Convex Finance", "Sun Token", "Hivemapper", "cat in a dogs world", "Vana", "Enjin Coin", "Lorenzo stBTC"
], vs_currencies='usd', include_market_cap='true', include_24hr_vol='true', include_24hr_change='true', include_last_updated_at='true')
# Out:
# {'1inch': {'usd': 0.209346, 'usd_market_cap': 288027708.3051061, 'usd_24h_vol': 25548574.740030125, 'usd_24h_change': -9.649136862886925, 'last_updated_at': 1741559736}, 'aave': {'usd': 176.87, 'usd_market_cap': 2666802415.666312, 'usd_24h_vol': 353081657.9392267, 'usd_24h_change': -10.110919053364704, 'last_updated_at': 1741559737}, 'abtc': {'usd': 81588, 'usd_market_cap': 175448238.1019021, 'usd_24h_vol': 768077.9172605941, 'usd_24h_change': -5.059833979220063, 'last_updated_at': 1741559735}, 'aelf': {'usd': 0.221975, 'usd_market_cap': 164034822.716501, 'usd_24h_vol': 11422970.741145559, 'usd_24h_change': -7.459462646590588, 'last_updated_at': 1741559735}, 'aethir': {'usd': 0.0321179, 'usd_market_cap': 215422036.71901193, 'usd_24h_vol': 29382804.9392282, 'usd_24h_change': -13.34310521296247, 'last_updated_at': 1741559736}, 'ai16z': {'usd': 0.192894, 'usd_market_cap': 211867908.1617927, 'usd_24h_vol': 61336823.093263075, 'usd_24h_change': -7.569915346465347, 'last_updated_at': 1741559736}, 'algorand': {'usd': 0.200544, 'usd_market_cap': 1698242115.0794148, 'usd_24h_vol': 102204965.55170238, 'usd_24h_change': -11.228301210814736, 'last_updated_at': 1741559737}, 'apecoin': {'usd': 0.465792, 'usd_market_cap': 371969908.58761144, 'usd_24h_vol': 49097485.59881688, 'usd_24h_change': -12.144023778243994, 'last_updated_at': 1741559737}, 'apenft': {'usd': 4.44139e-07, 'usd_market_cap': 439714963.41786605, 'usd_24h_vol': 17947679.265876543, 'usd_24h_change': -4.970617215944536, 'last_updated_at': 1741559736}, 'aptos': {'usd': 5.64, 'usd_market_cap': 3324526657.889346, 'usd_24h_vol': 198616061.15520367, 'usd_24h_change': -4.574131809110908, 'last_updated_at': 1741559737}, 'arbitrum': {'usd': 0.347027, 'usd_market_cap': 1532604783.6382768, 'usd_24h_vol': 149423282.176646, 'usd_24h_change': -12.930582523123935, 'last_updated_at': 1741559737}, 'arkham': {'usd': 0.48066, 'usd_market_cap': 177620331.81915557, 'usd_24h_vol': 62014559.1143105, 'usd_24h_change': -13.911277726075275, 'last_updated_at': 1741559736}, 'arweave': {'usd': 6.28, 'usd_market_cap': 410016369.50086564, 'usd_24h_vol': 36360799.4846194, 'usd_24h_change': -11.24193027725919, 'last_updated_at': 1741559736}, 'astar': {'usd': 0.02960776, 'usd_market_cap': 224708340.82148448, 'usd_24h_vol': 8001203.59287198, 'usd_24h_change': -8.741850926910502, 'last_updated_at': 1741559736}, 'axelar': {'usd': 0.36416, 'usd_market_cap': 337712320.52298784, 'usd_24h_vol': 18797690.01392123, 'usd_24h_change': -6.026605815482871, 'last_updated_at': 1741559736}, 'beam': {'usd': 0.02896771, 'usd_market_cap': 5154287.245186137, 'usd_24h_vol': 87321.32931690059, 'usd_24h_change': -7.288970835782937, 'last_updated_at': 1741559736}, 'beldex': {'usd': 0.068806, 'usd_market_cap': 476151551.80451965, 'usd_24h_vol': 2285573.1290519163, 'usd_24h_change': -3.9536875161521516, 'last_updated_at': 1741559736}, 'bitcoin': {'usd': 80987, 'usd_market_cap': 1609307556113.0623, 'usd_24h_vol': 28419594207.870243, 'usd_24h_change': -5.965315372029459, 'last_updated_at': 1741559728}, 'bittensor': {'usd': 239.49, 'usd_market_cap': 2020322358.6269455, 'usd_24h_vol': 108936290.79228844, 'usd_24h_change': -13.454783277532586, 'last_updated_at': 1741559737}, 'bittorrent': {'usd': 6.97922e-07, 'usd_market_cap': 692972839.6793355, 'usd_24h_vol': 26178820.314717434, 'usd_24h_change': -6.778915836988972, 'last_updated_at': 1741559737}, 'blur': {'usd': 0.101526, 'usd_market_cap': 227128340.8175362, 'usd_24h_vol': 22809439.726936214, 'usd_24h_change': -11.503939312099485, 'last_updated_at': 1741559722}, 'bonk': {'usd': 1.002e-05, 'usd_market_cap': 775605227.2240021, 'usd_24h_vol': 94697381.04851653, 'usd_24h_change': -13.980153159128205, 'last_updated_at': 1741559724}, 'brett': {'usd': 0.00073711, 'usd_market_cap': 0.0, 'usd_24h_vol': 4510.136517180577, 'usd_24h_change': -11.767996469652273, 'last_updated_at': 1741559655}, 'cardano': {'usd': 0.714027, 'usd_market_cap': 25756520571.34811, 'usd_24h_vol': 1410181128.6868086, 'usd_24 ...

# %%
df = pd.DataFrame(data).transpose()
df
# Out:
#             usd  usd_market_cap  usd_24h_vol  usd_24h_change  last_updated_at
# 1inch         0       288027708     25548575             -10       1741559736
# aave        177      2666802416    353081658             -10       1741559737
# abtc      81588       175448238       768078              -5       1741559735
# aelf          0       164034823     11422971              -7       1741559735
# aethir        0       215422037     29382805             -13       1741559736
# ...         ...             ...          ...             ...              ...
# worldcoin     0          539172           37             -17       1741559518
# wormhole      0       248929830     33076511             -13       1741559735
# zcash        30       471406511     23601097             -10       1741559735
# zilliqa       0       223565380     14076897              -9       1741559735
# zksync        0       254383356     43273025             -14       1741559736
#
# [142 rows x 5 columns]

# %%
df['last_updated_at'] = pd.to_datetime(df['last_updated_at'], unit='s')

# %%
df
# Out:
#             usd  usd_market_cap  usd_24h_vol  usd_24h_change  \
# 1inch         0       288027708     25548575             -10
# aave        177      2666802416    353081658             -10
# abtc      81588       175448238       768078              -5
# aelf          0       164034823     11422971              -7
# aethir        0       215422037     29382805             -13
# ...         ...             ...          ...             ...
# worldcoin     0          539172           37             -17
# wormhole      0       248929830     33076511             -13
# zcash        30       471406511     23601097             -10
# zilliqa       0       223565380     14076897              -9
# zksync        0       254383356     43273025             -14
#
#               last_updated_at
# 1inch     2025-03-09 22:35:36
# aave      2025-03-09 22:35:37
# abtc      2025-03-09 22:35:35
# aelf      2025-03-09 22:35:35
# aethir    2025-03-09 22:35:36
# ...                       ...
# worldcoin 2025-03-09 22:31:58
# wormhole  2025-03-09 22:35:35
# zcash     2025-03-09 22:35:35
# zilliqa   2025-03-09 22:35:35
# zksync    2025-03-09 22:35:36
#
# [142 rows x 5 columns]

# %%
df.reset_index(inplace=True)

# %%
df = df.rename(columns={'index': 'coins'})

# %%
df.dtypes
# Out:
# coins                      object
# usd                       float64
# usd_market_cap            float64
# usd_24h_vol               float64
# usd_24h_change            float64
# last_updated_at    datetime64[ns]
# dtype: object

# %%
import sqlalchemy as sal
engine = sal.create_engine('mssql://Kabir-Khan-PC/master?driver=ODBC+DRIVER+17+FOR+SQL+SERVER')
conn = engine.connect()

# %%
df.to_sql('crypto_info', con=conn, index=False, if_exists='replace')
# Out:
# 142

# %%
df
# Out:
#          coins   usd  usd_market_cap  usd_24h_vol  usd_24h_change  \
# 0        1inch     0       288027708     25548575             -10
# 1         aave   177      2666802416    353081658             -10
# 2         abtc 81588       175448238       768078              -5
# 3         aelf     0       164034823     11422971              -7
# 4       aethir     0       215422037     29382805             -13
# ..         ...   ...             ...          ...             ...
# 137  worldcoin     0          539172           37             -17
# 138   wormhole     0       248929830     33076511             -13
# 139      zcash    30       471406511     23601097             -10
# 140    zilliqa     0       223565380     14076897              -9
# 141     zksync     0       254383356     43273025             -14
#
#         last_updated_at
# 0   2025-03-09 22:35:36
# 1   2025-03-09 22:35:37
# 2   2025-03-09 22:35:35
# 3   2025-03-09 22:35:35
# 4   2025-03-09 22:35:36
# ..                  ...
# 137 2025-03-09 22:31:58
# 138 2025-03-09 22:35:35
# 139 2025-03-09 22:35:35
# 140 2025-03-09 22:35:35
# 141 2025-03-09 22:35:36
#
# [142 rows x 6 columns]
